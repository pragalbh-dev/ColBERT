# %%
print('zdfadfg\nasdfasd\n')
print('zdfadfg\nasdfasd\n')
print('zdfadfg %40 asdfasd\n')
# Out:
# zdfadfg
# asdfasd
#
# zdfadfg
# asdfasd
#
# zdfadfg \%40 asdfasd
# <>:3: SyntaxWarning: invalid escape sequence '\%'
# <>:3: SyntaxWarning: invalid escape sequence '\%'
# /var/folders/bk/nd8kztbd1yjd9yhl3cdt76kc0000gs/T/ipykernel_79336/3351622164.py:3: SyntaxWarning: invalid escape sequence '\%'
#   print('zdfadfg \%40 asdfasd\n')
