# %%
import pandas as pd

# %%
industries=pd.read_csv('/Users/pragalbh.devsingh/Downloads/sqllab_untitled_query_1_20250508T103526.csv')
industries=industries[['company_id','Company Name','industry']].rename(columns={'Company Name':'company_name','industry':'industry_chain_hierarchy'})

# %%
industries.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 industries.columns
#
# NameError: name 'industries' is not defined

# %%
industries.industry_chain_hierarchy.iloc[0]
# Out:
# 'Media & Entertainment > Video > Television > Streaming Platform'

# %%
industries[industries.industry_chain_hierarchy.str.contains('specific')].head().iloc[0].industry_chain_hierarchy
# Out:
# 'Enterprise > IT Software > Business Application > Advertising > Ad Buying & Selling Platform > Ad Exchange > Programmatic Platform > Kids-specific'

# %%
industries.to_csv('data/industries.csv',index=False)

# %%
import pandas as pd
factsheets=pd.read_parquet('/Users/pragalbh.devsingh/Downloads/all_factsheets_cleaned (1).parquet')

# %%
print(factsheets.sample(2).factsheet.to_list()[0])
print(factsheets.sample(2).factsheet.to_list()[1])
# Out:
# mifinda company fact sheet **
#
#  **1 .   company overview :**
#
#  mifinda provides a platform for managing and optimizing the entire lifecycle of digital assets , focusing on streamlining workflows and improving collaboration for creative teams .    their target market appears to be large enterprises and organizations with significant digital asset management needs .
#
#  **2 .   products , services , and offerings :**
#
#  mifinda offers a cloud - based digital asset management ( dam ) solution .    while specific features are n't exhaustively listed , the website emphasizes features designed to improve organization , collaboration , and workflow efficiency around digital assets .    this includes features for asset storage , organization , version control , and likely workflow automation tools .
#
#  **3 .   industry and target audience :**
#
# ...

# %%
factsheets.factsheet=factsheets.factsheet.str.replace(',',';')

# %%
factsheets.factsheet.iloc[0]
# Out:
# "the company company fact sheet **\n\n **company name :**gogo \n\n **website :**the company \n\n **products & services :**the company provides inflight internet connectivity and entertainment solutions for both commercial and business aviation .    their offerings include a range of connectivity solutions for various aircraft types and sizes ; utilizing a combination of satellite and air - to - ground ( atg ) technologies .    a key product is the the company avance system ; a factory - installed option available from major business aviation oems ; supported by a large mro network .    they emphasize a global network and redundancy for reliable connectivity .    the avance system uniquely offers dual network capabilities ( leo satellite and atg ) ; enabling bandwidth prioritization and service redundancy .   unlimited atg data plans include the company galileo data at no additional cost . \n\n **industry :**in - flight connectivity and entertainment \n\n **target audience :**airlines
# ...

# %%
factsheets.to_csv('data/all_factsheets_cleaned.csv',index=False)

# %%
import pandas as pd
industries =pd.read_csv('data/industries.csv')
factsheets =pd.read_csv('data/all_factsheets_cleaned.csv')

# %%
# industries.sample(5000).industry_chain_hierarchy.nunique()

# %%
overlapping_industries=industries.merge(industries,on='company_id',how='inner')
overlapping_industries=overlapping_industries[overlapping_industries.industry_chain_hierarchy_x!=overlapping_industries.industry_chain_hierarchy_y]
overlapping_industries=pd.concat([overlapping_industries[['company_id','industry_chain_hierarchy_x']].rename(columns={'industry_chain_hierarchy_x':'industry_chain_hierarchy'}),overlapping_industries[['company_id','industry_chain_hierarchy_y']].rename(columns={'industry_chain_hierarchy_y':'industry_chain_hierarchy'})])
overlapping_industries.to_csv('data/overlapping_industries.csv',index=False)
overlapping_industries.sort_values('company_id').iloc[:1000].to_csv('data/overlapping_industries_sample.csv',index=False)
overlapping_industries.sort_values('company_id').iloc[:100].to_csv('data/overlapping_industries_quickie.csv',index=False)
overlapping_industries.sample(10).to_csv('data/overlapping_industries_tiny.csv',index=False)

# %%
pd.concat([pd.read_csv('data/overlapping_industries_sample.csv'),industries[industries.industry_chain_hierarchy.isin(industries.industry_chain_hierarchy.drop_duplicates().sample(500))].sample(5000)]).to_csv('data/industries_sample.csv',index=False)

# %%
pd.concat([pd.read_csv('data/overlapping_industries_quickie.csv'),industries[industries.industry_chain_hierarchy.isin(industries.industry_chain_hierarchy.drop_duplicates().sample(100))].sample(100)]).drop_duplicates(subset=['company_id','industry_chain_hierarchy']).to_csv('data/industries_quickie.csv',index=False)
# industries[industries.industry_chain_hierarchy.isin(industries.industry_chain_hierarchy.drop_duplicates().sample(10))].sample(100).to_csv('data/industries_quickey.csv',index=False)

# %%
# pd.read_csv('data/overlapping_industries_quickie.csv')

# %%
sample_industries=pd.read_csv('data/industries_sample.csv')
quick_industries=pd.read_csv('data/industries_quickie.csv')

# %%
sample_industries.industry_chain_hierarchy.nunique()
# Out:
# 534

# %%
quick_industries
# Out:
#      company_id                           industry_chain_hierarchy  \
# 0             1  Media & Entertainment > Video > Television > S...
# 1             1  Consumer Product > Consumer Brand > Electronic...
# 2             1  Consumer Product > Consumer Brand > Electronic...
# 3             1  Consumer Product > Consumer Brand > Electronic...
# 4             2  Media & Entertainment > Video Gaming > Gaming ...
# ..          ...                                                ...
# 109      523708  Travel & Hospitality > Digital Solution > Soft...
# 110      433515  Industrials > Public Safety & Governance > Gov...
# 111      485860  Consumer Product > Consumer Brand > Electronic...
# 112     1429181  Travel & Hospitality > Digital Solution > Soft...
# 113      239861  Consumer Internet & Service > Service Provider...
#
#                     company_name
# 0                            NaN
# 1                            NaN
# 2                            NaN
# ...

# %%
sample_industries
# Out:
#       company_id                           industry_chain_hierarchy  \
# 0              1  Media & Entertainment > Video > Television > S...
# 1              1  Consumer Product > Consumer Brand > Electronic...
# 2              1  Media & Entertainment > Video > Television > S...
# 3              1  Consumer Product > Consumer Brand > Electronic...
# 4              1  Consumer Product > Consumer Brand > Electronic...
# ...          ...                                                ...
# 5995      214137  Consumer Product > Consumer Brand > Clothing, ...
# 5996       57924  Consumer Product > Consumer Brand > Clothing, ...
# 5997       67691  Energy & Utilities > Power Production > Solar ...
# 5998       10870  Travel & Hospitality > Digital Solution > Plat...
# 5999      125571  Consumer Product > Rental Platform > Clothing,...
#
#           company_name
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...

# %%
sample_industries.merge(sample_industries,on='company_id',how='inner')
# Out:
#       company_id                company_name_x  \
# 0        1104171          Artsploitation Films
# 1         395052         From Babies with Love
# 2         295667           Procurement Foundry
# 3         294041               We Make History
# 4         533083  Pacific Maritime Association
# ...          ...                           ...
# 4995      366340                           NRV
# 4996      219830                    eCompanies
# 4997      423404          La Fresque du Climat
# 4998      615690   Special Olympics Washington
# 4999      367063        Laticnios Porto Alegre
#
#                              industry_chain_hierarchy_x  \
# 0     Media & Entertainment > Video > Movie > Distri...
# 1     Non-Profit, Non-Operational & Junk > Non-Profi...
# 2     Non-Profit, Non-Operational & Junk > Non-Profi...
# 3     Non-Profit, Non-Operational & Junk > Non-Profi...
# 4     Non-Profit, Non-Operational & Junk > Non-Profi...
# ...

# %%
industries=pd.read_csv('data/industries.csv')

# %%
industries
# Out:
#         company_id        company_name  \
# 0                1               Apple
# 1                1               Apple
# 2                1               Apple
# 3                1               Apple
# 4                2             Ubisoft
# ...            ...                 ...
# 671936     1602549            Hairbook
# 671937     1602549            Hairbook
# 671938     1602553  Gaishishukatsu.com
# 671939     1602555              Roglio
# 671940     1602556           Mirroh.ai
#
#                                  industry_chain_hierarchy
# 0       Media & Entertainment > Video > Television > S...
# 1       Consumer Product > Consumer Brand > Electronic...
# 2       Consumer Product > Consumer Brand > Electronic...
# 3       Consumer Product > Consumer Brand > Electronic...
# 4       Media & Entertainment > Video Gaming > Gaming ...
# ...                                                   ...
# 671936  Consumer Internet & Service > Platform > Beaut...
# ...

# %%
# 1079527/671941

# %%
overlapping_industries
# Out:
#          company_id   company_name_x  \
# 1                 1            Apple
# 2                 1            Apple
# 3                 1            Apple
# 4                 1            Apple
# 6                 1            Apple
# ...             ...              ...
# 1079505     1602528  Zieg & Liphardt
# 1079512     1602535    Bad & Heizung
# 1079513     1602535    Bad & Heizung
# 1079521     1602549         Hairbook
# 1079522     1602549         Hairbook
#
#                                 industry_chain_hierarchy_x   company_name_y  \
# 1        Media & Entertainment > Video > Television > S...            Apple
# 2        Media & Entertainment > Video > Television > S...            Apple
# 3        Media & Entertainment > Video > Television > S...            Apple
# 4        Consumer Product > Consumer Brand > Electronic...            Apple
# 6        Consumer Product > Consumer Brand > Electronic...            Apple
# ...

# %%
sample_industries
# Out:
#       company_id                  company_name  \
# 0        1104171          Artsploitation Films
# 1         395052         From Babies with Love
# 2         295667           Procurement Foundry
# 3         294041               We Make History
# 4         533083  Pacific Maritime Association
# ...          ...                           ...
# 4995      366340                           NRV
# 4996      219830                    eCompanies
# 4997      423404          La Fresque du Climat
# 4998      615690   Special Olympics Washington
# 4999      367063        Laticnios Porto Alegre
#
#                                industry_chain_hierarchy
# 0     Media & Entertainment > Video > Movie > Distri...
# 1     Non-Profit, Non-Operational & Junk > Non-Profi...
# 2     Non-Profit, Non-Operational & Junk > Non-Profi...
# 3     Non-Profit, Non-Operational & Junk > Non-Profi...
# 4     Non-Profit, Non-Operational & Junk > Non-Profi...
# ...                                                 ...
# ...

# %%
factsheets[factsheets.company_id.isin(sample_industries.company_id)].to_csv('data/all_factsheets_cleaned_sample.csv',index=False)
factsheets[factsheets.company_id.isin(quick_industries.company_id)].to_csv('data/all_factsheets_cleaned_quickey.csv',index=False)

# %%
quick_industries

# %%
dataset=pd.read_csv('/Users/pragalbh.devsingh/Documents/work/models/ColBERT/knowledge_data_curation/output/colbert_training/colbert_training_data.csv')

# %%
dataset
# Out:
#                                                    query  \
# 0      Biotechnology > Biomedicine Research > Molecul...
# 1      Biotechnology > Biomedicine Research > Molecul...
# 2      Biotechnology > Biomedicine Research > Molecul...
# 3      Biotechnology > Biomedicine Research > Molecul...
# 4      Biotechnology > Biomedicine Research > Molecul...
# ...                                                  ...
# 43297  Service > IT Implementation & Integration > Ou...
# 43298  Service > IT Implementation & Integration > Ou...
# 43299  Service > IT Implementation & Integration > Ou...
# 43300  Service > IT Implementation & Integration > Ou...
# 43301  Service > IT Implementation & Integration > Ou...
#
#                                                factsheet  score  is_positive
# 0      the company company fact sheet **\n\n **1 .   ...    1.0         True
# 1      the company fact sheet **\n\n **company name :...    1.0         True
# ...

# %%
import json
cleaned_chain_dict=json.loads(open('/Users/pragalbh.devsingh/Documents/work/models/ColBERT/knowledge_data_curation/output/cleaned_chains/cleaned_chains.json').read())

# %%
list(cleaned_chain_dict.keys())
# Out:
# ['Enterprise > Add-on > Enterprise Software > HR Tech > Payroll Management Solution',
#  'Lifestyle > Application > Consumer Internet & Service > Product Discovery, Comparison & Recommendation > Chat-based > Product Discovery > Multiline',
#  'Technology > Detection & Ranging > RFID & NFC Reader > Semiconductor > System-on-a-Chip > Fabless',
#  'Technology > Smart Lock > Physical Access Control > Internet of Things > Commercial IoT > IoT Application > Connected Building > Safety & Security',
#  'Technology > AI Application > Chemical Industry > Business Function-Specific > Artificial Intelligence > R&D Management Solution',
#  'Technology > Manufacturer > 3D Printing > Printer > Stereolithography Printers',
#  'Healthcare & Life Sciences > Intensive Care Unit > Digital Health > Health Care IT > Hospital Management & Information System > EHR Platform & Practice Management',
# ...

# %%
cleaned_chain_dict['Financial Industry > Backend Solution > InsureTech > Product Pricing Solution > Insurer Solution > FinTech']


cleaned_chain_dict['Consumer Product > Clothing, Accessories & Footwear > Fabric > Nylon & Polyester > B2B Manufacturer > Component']
# Out:
# 'Consumer Product > Clothing, Accessories & Footwear > Fabric > Nylon & Polyester > Component'

# %%
negative_chains=json.loads(open('/Users/pragalbh.devsingh/Documents/work/models/ColBERT/knowledge_data_curation/output/negative_chains/negative_chains.json').read())

# %%
import random
random.sample(list(negative_chains.keys()),10)
# Out:
# ['FinTech > Financial Industry > Security Solution > Merchant Payment Solution > Security & Compliance Solution > Payment Recall > Payments',
#  'Test, Measurement & Instrumentation > Resistivity & Induced Polarization Meter > Polarization Meter > Measurement & Calibration',
#  'IoT Application > Connected Building > Commercial IoT > Internet of Things > Physical Access Control > Safety & Security',
#  'Enterprise > Enterprise Software > Product Analytics > Design Analytics > Product Management',
#  'Agriculture > Agriculture, Food & Beverage > Food Safety & Quality > Testing Platform > Agri Tech > Produce Inspection',
#  'Automotive > Transport Tech > Mobility > Parking Payment > Payment Solution > B2C',
#  'Educational Institution > Basketball > Sports & Fitness > Skill Development',
#  'Financial Industry > Consulting > Auditing Solution > Financial Service > Service for Businesses',
# ...

# %%
negative_chains['IoT Application > Connected Building > Commercial IoT > Internet of Things > Physical Access Control > Safety & Security']
# Out:
# {'hard_negatives': ['Technology > Outsourcing > Custom AI Development > Security & Surveillance > AI Service > Artificial Intelligence > Industrials > Industry-Specific',
#   'Service > Technology > Electronics Ecosystem',
#   'Technology > Thermal Image Sensor > Electronic Component > Sensor > Electronics Ecosystem > Manufacturer > Imaging',
#   'Industrials > Engineering, Research & Development > Software > Data Provider > Safety Data > Material & Chemical',
#   'Inland & Maritime > Mobility > Enterprise Software > Inspection, Maintenance & Repair > Vessel & Fleet Management > Operation & Maintenance',
#   'Technology > Wearable Camera > Commercial',
#   'Healthcare & Life Sciences > Health Care IT > Financial Management Solution > Digital Health > Hospital Management & Information System'],
#  'soft_negatives': ['Energy & Utilities > Utilities > Gas Utilities > Infrastructure > Distribution > Service',
#   'Consumer Brand > Candle > Home Fragrance > Home Furnishing > Home Decor',
# ...

# %%
# industries[industries.industry_chain_hierarchy.str.contains('Financial Industry > Backend Solution')]

# %%
# dataset.factsheet.iloc[345]

# %%
# sample=pd.read_csv('data/all_factsheets_cleaned_sample.csv')

# %%
# sample.factsheet.iloc[0]

# %%
import sys
sys.path.append('/Users/pragalbh.devsingh/Documents/work/models/ColBERT/')
from knowledge_data_curation.src.data_processors.negative_generator import NegativeSampleGenerator

# %%
from knowledge_data_curation.src.pipelines.main_pipeline import ColBERTTrainingPipeline

# %%
data_curator=ColBERTTrainingPipeline(config_path='config/default.yaml')
# Out:
# 2025-05-08 19:11:23,556 - knowledge_data_curation.src.utils.token_counter - INFO - Initialized token counter
# 2025-05-08 19:11:23,556 - knowledge_data_curation.src.models.llm_client - INFO - Initialized OpenAI client with model=gpt-4.1-mini, max_threads=2
# 2025-05-08 19:11:23,557 - knowledge_data_curation.src.models.llm_client - INFO - Initialized OpenAI client with model=gpt-4.1-mini, max_threads=2

# %%
# negative_chains['IoT Application > Connected Building > Commercial IoT > Internet of Things > Physical Access Control > Safety & Security']

# %%
chain='IoT Application > Connected Building > Commercial IoT > Internet of Things > Physical Access Control > Safety & Security'
negative_chains = data_curator.negative_generator.generate_negatives_for_chain(chain)
# Out:
# 2025-05-08 19:11:25,578 - knowledge_data_curation.src.models.llm_client - INFO - Using response format: <class 'knowledge_data_curation.src.models.pydantic.NegativeSamplingResponse'>
# 2025-05-08 19:11:29,681 - knowledge_data_curation.src.utils.token_counter - INFO - Token usage - Total: 1,013 (Prompt: 839, Completion: 174)

# %%
negative_chains.hard_negatives
# Out:
# ['Technology > Internet of Things > Infrastructure > Connectivity > Networking > IoT Gateway > Industry-Specific > Industrial IoT',
#  'Technology > Internet of Things > Infrastructure > Tracking & Navigation',
#  'Industrials > Public Safety & Governance > Software > Communication > Open Data Platform',
#  'Enterprise > IT Infrastructure > Cybersecurity > Identity & Access Management > Identity Management > Decentralized Identity Management']

# %%
negative_chains
# Out:
# NegativeSamplingResponse(hard_negatives=['Enterprise > IT Software > Business Application > Productivity & Collaboration > Business Contact Management > Digital Business Card', 'Industrials > Business Product & Service > Manufacturer > Furnishing > Space-Based > Residential', 'Enterprise > IT Software > Business Application > Human Resources > Candidate Sourcing > Freelancer > Private Security Professionals'], soft_negatives=['Financial Industry > FinTech > Trading & Investment > Trading Platform > Public Market > Exchange-Traded Fund', 'Media & Entertainment > Software > Production > Feedback Management', 'Industrials > Industrial Production > Machinery & Equipment > Fluid Transfer Equipment > Pump & Compressor', 'Technology > Artificial Intelligence > Business Function-Specific > Customer Service & Support > Feedback Tool', 'Financial Industry > FinTech > Finance & Accounting > Taxation Software > Transfer Pricing'])

# %%
import pandas as pd
industries=pd.read_csv('data/industries_quickie.csv')
company_factsheets=pd.read_csv('data/all_factsheets_cleaned.csv')

# %%
company_factsheets_quickie=company_factsheets[company_factsheets.company_id.isin(industries.company_id)]
company_factsheets_quickie.to_csv('data/all_factsheets_cleaned_quickie.csv',index=False)

# %%
# industries[industries.company_id.isin(company_factsheets.company_id)]

# %%
# industries['industry_chain_hierarchy'].value_counts()

# %%
import pandas as pd

augmented_ind_df=pd.read_csv('/Users/pragalbh.devsingh/Documents/work/models/ColBERT/knowledge_data_curation/output/synthetic_data_cache/integrated_augmented_industry_data.csv')

augmented_factsheet_df=pd.read_csv('/Users/pragalbh.devsingh/Documents/work/models/ColBERT/knowledge_data_curation/output/synthetic_data_cache/integrated_augmented_factsheet_data.csv')

# %%
import pandas as pd

ind_df=pd.read_csv('/Users/pragalbh.devsingh/Documents/work/models/ColBERT/knowledge_data_curation/data/industries_quickie.csv')
factsheet_df=pd.read_csv('/Users/pragalbh.devsingh/Documents/work/models/ColBERT/knowledge_data_curation/data/all_factsheets_cleaned_quickie.csv')

# %%
augmented_factsheet_df
# Out:
#                  company_id                                          factsheet
# 0                         1  company fact sheet : the company inc . **\n\n ...
# 1                     17087  company fact sheet : the company **\n\n **1 . ...
# 2                     41735  numat fact sheet **\n\n **company name :**numa...
# 3                     55111  inipower company fact sheet **\n\n **1 .   com...
# 4                    115596  vectra global fact sheet **\n\n **company name...
# ..                      ...                                                ...
# 151  synthetic_3b7dde81c886  Products / Services / Offerings: Vertex Interi...
# 152  synthetic_13e430bcb589  Products / Services / Offerings: CVStreamX pro...
# 153  synthetic_d56bfd775d0e  Products / Services / Offerings: StreamSight I...
# 154  synthetic_e3d0e837bea4  Products / Services / Offerings: ADNexis provi...
# 155  synthetic_278782bd7a1c  Products / Services / Offerings: SearchAdLink7...
#
# [156 rows x 2 columns]

# %%
augmented_ind_df
# Out:
#                  company_id  \
# 0                         1
# 1                         1
# 2                         1
# 3                         1
# 4                         2
# ..                      ...
# 179  synthetic_3b7dde81c886
# 180  synthetic_13e430bcb589
# 181  synthetic_d56bfd775d0e
# 182  synthetic_e3d0e837bea4
# 183  synthetic_278782bd7a1c
#
#                               industry_chain_hierarchy company_name
# 0    Media & Entertainment > Video > Television > S...          NaN
# 1    Consumer Product > Consumer Brand > Electronic...          NaN
# 2    Consumer Product > Consumer Brand > Electronic...          NaN
# 3    Consumer Product > Consumer Brand > Electronic...          NaN
# 4    Media & Entertainment > Video Gaming > Gaming ...          NaN
# ..                                                 ...          ...
# 179  Real Estate & Construction > Construction > Ma...          NaN
# 180  Technology > Artificial Intelligence > Infrast...          NaN
# ...

# %%
import pandas as pd

aug_data=pd.merge(augmented_ind_df,augmented_factsheet_df,on='company_id',how='left')

# %%
aug_data[aug_data.company_id.str.contains('synthetic_')].head(10)
# Out:
#                  company_id  \
# 114  synthetic_b84b84819f8c
# 115  synthetic_925df415d31e
# 116  synthetic_6dea8a87131b
# 117  synthetic_92b62ff5885d
# 118  synthetic_69802f24302e
# 119  synthetic_b49797e660a7
# 120  synthetic_f3cc8264ffc8
# 121  synthetic_6802f5738100
# 122  synthetic_df97d796be2d
# 123  synthetic_d6b5edaaadf5
#
#                               industry_chain_hierarchy company_name  \
# 114  Enterprise > IT Infrastructure > IT Operations...          NaN
# 115  Enterprise > IT Infrastructure > IT Operations...          NaN
# 116  Enterprise > IT Software > Business Applicatio...          NaN
# 117  Enterprise > IT Software > Business Applicatio...          NaN
# 118  Consumer Product > Consumer Brand > Electronic...          NaN
# 119  Consumer Product > Consumer Brand > Electronic...          NaN
# 120  Technology > Artificial Intelligence > Applica...          NaN
# 121  Technology > Artificial Intelligence > Applica...          NaN
# ...

# %%
syn_comp_id='synthetic_f3cc8264ffc8'
print(aug_data[aug_data.company_id==syn_comp_id].industry_chain_hierarchy.iloc[0])
print(aug_data[aug_data.company_id==syn_comp_id].factsheet.iloc[0])
# Out:
# Technology > Artificial Intelligence > Application > Industry-Specific > Consumer > Utility & Productivity > Content Summary Generator
# Products / Services / Offerings: Summalyze provides an AI-driven content summarization platform that generates concise, context-aware summaries from lengthy documents and multimedia content.
# Industry & Target Audience: Operating within the AI software application sector, Summalyze targets enterprises and content creators requiring efficient content digestion tools.
# Business Model: The company operates a SaaS model delivering subscription-based access to its summarization APIs and user interface.
# Revenue Model: Revenue is generated through tiered subscriptions and API usage fees with additional premium customization services.
# Technology Used: Summalyze leverages advanced transformer-based deep learning models and natural language understanding techniques for accurate content summarization.

# %%
aug_data[~(aug_data.company_id=='synthetic_15af2f610aa3') & (aug_data.industry_chain_hierarchy=='Media & Entertainment > Video > Television > Streaming Platform')]
# Out:
#                  company_id  \
# 0                         1
# 123  synthetic_11a444dda42b
#
#                               industry_chain_hierarchy company_name  \
# 0    Media & Entertainment > Video > Television > S...          NaN
# 123  Media & Entertainment > Video > Television > S...          NaN
#
#                                              factsheet
# 0    company fact sheet : the company inc . **\n\n ...
# 123  company fact sheet : FlickStream Inc. **\n\n**...

# %%
ind_df.groupby('industry_chain_hierarchy').transform(len)
# Out:
#      company_id  company_name
# 0             1             1
# 1             1             1
# 2             1             1
# 3             1             1
# 4             1             1
# ..          ...           ...
# 109          12            12
# 110           3             3
# 111           1             1
# 112          12            12
# 113           4             4
#
# [114 rows x 2 columns]

# %%
len(ind_df[ind_df.groupby('industry_chain_hierarchy').company_id.transform(len)<2])
# Out:
# 36

# %%
ind_df[(~ind_df.industry_chain_hierarchy.isin(aug_data[aug_data.company_id.str.contains('syn')].industry_chain_hierarchy)) & (ind_df.groupby('industry_chain_hierarchy').company_id.transform(len)<2) ]
# Out:
#      company_id                           industry_chain_hierarchy  \
# 103      153799  Education > EdTech > Higher Education > Studen...
#
#     company_name
# 103     Pairprep

# %%
aug_data[(aug_data.company_id.str.contains('syn')) & (aug_data.industry_chain_hierarchy.isin())]

# %%
aug_data[aug_data.company_id.str.contains('syn')]
# Out:
#                  company_id  \
# 114  synthetic_47278bdfb8c8
# 115  synthetic_0844d5e15e0b
# 116  synthetic_4e31084ebd71
# 117  synthetic_6f9daa276e1a
# 118  synthetic_471076485e70
# ..                      ...
# 179  synthetic_78cd1b2cf117
# 180  synthetic_229fca2b2081
# 181  synthetic_990c982cc669
# 182  synthetic_9127c795f22b
# 183  synthetic_2dbbfdb33d73
#
#                               industry_chain_hierarchy company_name  \
# 114  Consumer Product > Consumer Brand > Electronic...          NaN
# 115  Consumer Product > Consumer Brand > Electronic...          NaN
# 116  Consumer Internet & Service > Application > Ut...          NaN
# 117  Consumer Internet & Service > Application > Ut...          NaN
# 118  Enterprise > IT Software > Business Applicatio...          NaN
# ..                                                 ...          ...
# 179  Technology > Semiconductor > Integrated Device...          NaN
# 180  Consumer Product > B2B Manufacturer > Clothing...          NaN
# ...

# %%
print(aug_data[~(aug_data.company_id=='synthetic_15af2f610aa3') & (aug_data.industry_chain_hierarchy=='Media & Entertainment > Video > Television > Streaming Platform')].factsheet.iloc[0])
# Out:
# company fact sheet : the company inc . **
#
#  **1 .   company overview :**
#
#  the company inc .   is a multinational technology company headquartered in cupertino ; california .    it designs ; develops ; and sells consumer electronics ; computer software ; and online services .
#
#  **2 .   products ; services ; and offerings :**
#
#  *** hardware :**  iphones ; ipads ; macs ( desktops and laptops ) ; the company watch ; airpods ; the company tv ; the company vision pro ; and various accessories .
#  *** software :**macos ; ios ; ipados ; watchos ; tvos ; and various productivity and creativity applications .
#  *** services :**  app store ; the company music ; the company tv+ ; icloud ; the company arcade ; the company fitness+ ; the company pay ; the company news+ ; and other subscription services .
#
#  **3 .   industry and target audience :**
#
# ...

# %%
import pandas as pd

ind_df=pd.read_csv('/Users/pragalbh.devsingh/Documents/work/models/ColBERT/knowledge_data_curation/data/industries_quickie.csv')
factsheet_df=pd.read_csv('/Users/pragalbh.devsingh/Documents/work/models/ColBERT/knowledge_data_curation/data/all_factsheets_cleaned_quickie.csv')

print(ind_df[ind_df.industry_chain_hierarchy=='Technology > Semiconductor > Integrated Device Manufacturer > Analog & Mixed Signal > Multiline'].company_id.to_list(),ind_df[ind_df.industry_chain_hierarchy=='Technology > Semiconductor > Integrated Device Manufacturer > Analog & Mixed Signal > Multiline'].company_id.nunique())
# Out:
# [1328511] 1

# %%
print(factsheet_df.factsheet.iloc[0])
# Out:
# company fact sheet : the company inc . **
#
#  **1 .   company overview :**
#
#  the company inc .   is a multinational technology company headquartered in cupertino ; california .    it designs ; develops ; and sells consumer electronics ; computer software ; and online services .
#
#  **2 .   products ; services ; and offerings :**
#
#  *** hardware :**  iphones ; ipads ; macs ( desktops and laptops ) ; the company watch ; airpods ; the company tv ; the company vision pro ; and various accessories .
#  *** software :**macos ; ios ; ipados ; watchos ; tvos ; and various productivity and creativity applications .
#  *** services :**  app store ; the company music ; the company tv+ ; icloud ; the company arcade ; the company fitness+ ; the company pay ; the company news+ ; and other subscription services .
#
#  **3 .   industry and target audience :**
#
# ...

# %%
## issues identified:

ind_df
# Out:
#      company_id                           industry_chain_hierarchy  \
# 0             1  Media & Entertainment > Video > Television > S...
# 1             1  Consumer Product > Consumer Brand > Electronic...
# 2             1  Consumer Product > Consumer Brand > Electronic...
# 3             1  Consumer Product > Consumer Brand > Electronic...
# 4             2  Media & Entertainment > Video Gaming > Gaming ...
# ..          ...                                                ...
# 109      523708  Travel & Hospitality > Digital Solution > Soft...
# 110      433515  Industrials > Public Safety & Governance > Gov...
# 111      485860  Consumer Product > Consumer Brand > Electronic...
# 112     1429181  Travel & Hospitality > Digital Solution > Soft...
# 113      239861  Consumer Internet & Service > Service Provider...
#
#                     company_name
# 0                            NaN
# 1                            NaN
# 2                            NaN
# ...

# %%
import pandas as pd

all_ind_df=pd.read_csv('/Users/pragalbh.devsingh/Documents/work/models/ColBERT/knowledge_data_curation/data/industries.csv')
all_factsheet_df=pd.read_csv('/Users/pragalbh.devsingh/Documents/work/models/ColBERT/knowledge_data_curation/data/all_factsheets_cleaned.csv')

# %%
df=all_ind_df.merge(all_factsheet_df)

# %%
import pandas as pd


count_df=df.groupby('industry_chain_hierarchy').company_id.nunique().reset_index().sort_values(by='company_id', ascending=False)

# %%
count_df
# Out:
#                                 industry_chain_hierarchy  company_id
# 26643  Non-Profit, Non-Operational & Junk > Non-Profi...        9844
# 26642  Non-Profit, Non-Operational & Junk > Non-Opera...        5492
# 14640  Financial Industry > Financial Institution > A...        5171
# 12920  Enterprise > Service > Outsourcing > Informati...        3950
# 14719  Financial Industry > Financial Institution > B...        2370
# ...                                                  ...         ...
# 2129   Agriculture, Food & Beverage > Food & Beverage...           1
# 2128   Agriculture, Food & Beverage > Food & Beverage...           1
# 13450  Financial Industry > FinTech > Finance & Accou...           1
# 21009  Industrials > Environment > Conservation & Pre...           1
# 12393  Enterprise > Service > Outsourcing > Business ...           1
#
# [32878 rows x 2 columns]

# %%
to_create_fatchseet=count_df[count_df.company_id<5]

# %%
to_create_fatchseet
# Out:
#                                 industry_chain_hierarchy  company_id
# 28944  Technology > Artificial Intelligence > Applica...           4
# 26116  Mobility > Aviation > Manufacturer > Aircraft ...           4
# 5703   Consumer Product > Retailer > Houseware & Home...           4
# 25905  Mobility > Automotive > Software > Business Ma...           4
# 32342  Travel & Hospitality > Digital Solution > Plat...           4
# ...                                                  ...         ...
# 2129   Agriculture, Food & Beverage > Food & Beverage...           1
# 2128   Agriculture, Food & Beverage > Food & Beverage...           1
# 13450  Financial Industry > FinTech > Finance & Accou...           1
# 21009  Industrials > Environment > Conservation & Pre...           1
# 12393  Enterprise > Service > Outsourcing > Business ...           1
#
# [18191 rows x 2 columns]

# %%
to_create_fatchseet['n']=5-to_create_fatchseet.company_id
# Out:
# /var/folders/bk/nd8kztbd1yjd9yhl3cdt76kc0000gs/T/ipykernel_1794/3511335916.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_create_fatchseet['n']=5-to_create_fatchseet.company_id

# %%
factsheets_required_to_be_created=57480
chains_to_create_factsheets_for=18191

out_toks=factsheets_required_to_be_created*500/1000000
out_cost=out_toks*1.60

in_toks=chains_to_create_factsheets_for*2000/1000000
in_cost=in_toks*0.40

# %%
to_create_fatchseet.n.sum()
# Out:
# np.int64(57480)

# %%
out_toks=57480*500/1000000
out_cost=out_toks*1.60

# %%
in_toks=57480*1000/1000000
in_cost=in_toks*0.40

# %%
in_cost+out_cost
# Out:
# 60.5368

# %%
32000*0.3/50
# Out:
# 192.0

# %%
## cost for industry negative sampling
avg_token_per_chain=30

# %%
input_chains_per_negative_sampling=32

# %%
1,2,3,4,5,6,7

# %%
len([
  "Enterprise>Service>Outsourcing",
  "Power Production",
  "Education>EdTech>Higher Education",
  "Interior Solution",
  "Canada-Focused",
  "Public Safety & Governance",
  "Higher Education",
  "Media & Entertainment>Video Gaming>Game Publisher",
  "Modeling & Simulation",
  "Visual Analysis",
  "Employee Benefits Solution",
  "Consumer Product",
  "Application",
  "Building Solution",
  "Advertising",
  "Consumer Product>Consumer Brand>Electronic Product",
  "IT Service Management",
  "Content & Experience Marketing",
  "Video Gaming",
  "Business & Finance",
  "Gastroenterology",
  "Retail",
  "Occupational Health Management",
  "Digital>News>Medical",
  "Ad Buying & Selling Platform>Ad Network>Search Advertising Network",
  "Manufacturer",
  "Streaming Analytics",
  "Compliance Solution",
  "IT Software",
  "Sport, Fitness & Outdoor Product>Equipment>Gym",
  "Utility",
  "Technology>Semiconductor>Integrated Device Manufacturer",
  "Online",
  "Travel & Hospitality",
  "Sale, Leasing & Management>Agency & Brokerage>Software",
  "Thermal Energy",
  "Industrials>Industrial Production>Software",
  "Internet of Things",
  "Agency & Brokerage",
  "Financial Management",
  "Material & Chemical",
  "Personal Appliance",
  "Computer Vision>Visual Analysis>Streaming Analytics",
  "Television",
  "Industry-Specific>Consumer>Utility & Productivity",
  "Ad Network",
  "Store Automation Solution",
  "Outsourcing",
  "Application>Industry-Specific>Retail",
  "Asset Management & Disposition",
  "Solar Product",
  "Consumer Internet & Service>Application>Lifestyle",
  "Service",
  "Speaker & Sound Bar",
  "Lifestyle",
  "Consumer Brand",
  "Task Management",
  "Gym",
  "Restaurant, Cafe & Bar",
  "Sales",
  "Sale, Leasing & Management",
  "Outsourcing>Information Technology>Software Testing",
  "Commercial IoT",
  "Computer, Mobile & Accessories",
  "Asset Tracking",
  "Connected Logistics",
  "Integrated Device Manufacturer",
  "Streaming Platform",
  "Consumer Product>Recreational & Leisure>Sport, Fitness & Outdoor Product",
  "Real Estate & Construction>Construction>Building Solution",
  "Digital Learning>Entrance Exam>Q&A Platform",
  "Distributor",
  "Email Solution",
  "Social Media",
  "Marketing",
  "Online Forum",
  "Language Learning",
  "Detector",
  "Building Solution>Interior Solution>Floor",
  "Lifestyle>Product Discovery, Comparison & Recommendation>Apparel, Accessories & Footwear",
  "Industry-Specific",
  "Utility>Internet Browser>Search Engine",
  "Computer & Console Gaming",
  "Consumer Internet & Service>Application>Utility",
  "Ad Buying & Selling Platform",
  "Utility & Productivity",
  "Technology",
  "Education>EdTech>Skill Development",
  "Security & Safety",
  "Student Solution",
  "Communication Platform",
  "Clothing, Accessories & Footwear",
  "Search Engine",
  "Human Resources",
  "Governance>Software>Administration & Management Platform",
  "Consumer Product>Electronic Product>Home Appliance",
  "Consumer Product>Electronic Product>Personal Appliance",
  "Home Care Product",
  "Ad Exchange",
  "Devotional Product",
  "Power Generation Unit",
  "Houseware & Home Supplies",
  "Media & Entertainment>Video Gaming>Gaming Studio",
  "Web & Mobile Gaming",
  "Software Solution>Hospitality>Restaurant, Cafe & Bar",
  "Sport, Fitness & Outdoor Product",
  "Agriculture, Food & Beverage>Food & Beverage>Distributor",
  "Enterprise>IT Infrastructure>IT Operations",
  "Ad Buying & Selling Platform>Ad Exchange>Online",
  "Higher Education>Student Solution>Digital Learning",
  "Email",
  "Power System",
  "Data Security",
  "Wellness Service",
  "Education",
  "Technology>Artificial Intelligence>Computer Vision",
  "Specialty Medical Device>Gastroenterology>Therapeutic Device",
  "Personal Development",
  "Digital Rights Management",
  "Administration & Management Platform",
  "Healthcare & Life Sciences",
  "Fixtures, Fittings & Finishes",
  "Smart Watch",
  "Skill Development",
  "Task Tracking",
  "Energy & Utilities>Power Production>Thermal Energy",
  "Computer Vision",
  "Internet Browser",
  "Digital>News>Business & Finance",
  "Business Application>Productivity & Collaboration>Project Management",
  "Digital Solution",
  "Thermal Energy>Power System>Power Generation Unit",
  "Consumer Product>Consumer Brand>Houseware & Home Supplies",
  "Medical",
  "Technology>Artificial Intelligence>Application",
  "Learning Material",
  "Employee Benefits Solution>Healthcare>Occupational Health Management",
  "Wearable",
  "Personal Appliance>Wearable>Smart Watch",
  "Recreational & Leisure",
  "Media & Entertainment>Video>Television",
  "Audience Data",
  "Enterprise>IT Infrastructure>Cybersecurity",
  "Digital",
  "Project Management",
  "Home Appliance>Entertainment>Home Audio",
  "Enterprise>IT Software>Marketing",
  "Content Summary Generator",
  "IT Asset Management",
  "Business Application>Marketing>Marketing Management",
  "Industrials>Public Safety & Governance>Governance",
  "Business & Finance>Startup & Entrepreneurship>Newsletters",
  "Food & Beverage",
  "Business Application>Sales>Sales Intelligence Platform",
  "Home Audio>Speaker & Sound Bar>Smart Speaker",
  "Industrials",
  "Game Publisher",
  "Enterprise>IT Software>Business Application",
  "Cybersecurity",
  "Software",
  "Consumer Internet & Service",
  "Houseware & Home Supplies>Home Care Product>Devotional Product",
  "Technology>Artificial Intelligence>Machine Learning",
  "Apparel, Accessories & Footwear",
  "Component",
  "Energy & Utilities>Power Production>Solar Energy",
  "EdTech",
  "Electronic Product>Personal Appliance>Computer, Mobile & Accessories",
  "Entertainment",
  "Skill Development>Personal Development>Language Learning",
  "Business Application",
  "Real Estate & Construction",
  "Energy & Utilities",
  "IT Operations>IT Service Management>IT Asset Management",
  "Home Appliance",
  "Specialty Medical Device",
  "Consumer Internet & Service>Social Media>Online Forum",
  "Smoke Detector",
  "Marketing Management",
  "Cybersecurity>Data Security>Digital Rights Management",
  "Digital Learning",
  "IT Operations",
  "Artificial Intelligence",
  "IT Infrastructure",
  "Media & Entertainment",
  "Model Hosting",
  "Marketing Management>Content & Experience Marketing>Content Marketing",
  "Software Testing",
  "Beauty & Wellness",
  "Startup & Entrepreneurship",
  "Sales Intelligence Platform",
  "Business Application>Advertising>Ad Buying & Selling Platform",
  "Productivity & Collaboration",
  "Entrance Exam",
  "Tracking & Monitoring",
  "Software>Financial Management>Compliance Solution",
  "News",
  "Denim",
  "Component>Fabric>Denim",
  "Enterprise",
  "Newsletters",
  "Research & Development",
  "Software>Product Management>Modeling & Simulation",
  "Semiconductor",
  "Consumer Product>Clothing, Accessories & Footwear>Component",
  "Product Management",
  "Media & Entertainment>Books, News & Magazine>Digital",
  "Therapeutic Device",
  "Technology>Artificial Intelligence>Industry-Specific",
  "Dry Ice",
  "Home Audio",
  "Apheresis Therapy Device",
  "Gaming Studio",
  "Product Discovery",
  "Equipment",
  "Search Advertising Network",
  "Healthcare & Life Sciences>Device & Equipment>Laboratory & Research Equipment",
  "Consumer Internet & Service>Beauty & Wellness>Wellness Service",
  "Device & Equipment",
  "Project Documentation",
  "Q&A Platform",
  "Healthcare",
  "Business Application>Human Resources>Employee Benefits Solution",
  "Healthcare & Life Sciences>Device & Equipment>Specialty Medical Device",
  "Floor",
  "Video",
  "Industrial Production",
  "Solar Energy>Manufacturer>Solar Product",
  "Construction",
  "Business Application>Productivity & Collaboration>Communication Platform",
  "Content Marketing",
  "Machine Learning",
  "Governance",
  "Electronic Product",
  "Information Technology",
  "Books, News & Magazine",
  "Product Discovery, Comparison & Recommendation",
  "Real Estate & Construction>Digital Solution>Sale, Leasing & Management",
  "Fabric",
  "Smart Speaker",
  "Technology>Internet of Things>Commercial IoT",
  "Consumer",
  "Home Appliance>Security & Safety>Detector",
  "Software Solution",
  "Industrials>Material & Chemical>Research & Development",
  "Agriculture, Food & Beverage",
  "Solar Energy",
  "Commercial IoT>Connected Logistics>Tracking & Monitoring",
  "Analog & Mixed Signal",
  "Project Management>Task Management>Task Tracking",
  "Hospitality",
  "Laboratory & Research Equipment",
  "Psychographic Intelligence",
  "Travel & Hospitality>Digital Solution>Software Solution"
])
# Out:
# 254

# %%
tokens_in_sample_subchains=1944
avg_tokens_per_subchain=tokens_in_sample_subchains/254

# %%
avg_tokens_per_subchain
# Out:
# 7.653543307086614

# %%
# total1,944

# %%
number_of_chains=50
number_of_subchains=254
avg_subchain_per_chain=number_of_subchains/number_of_chains

# %%
avg_subchain_per_chain
# Out:
# 5.08

# %%
total_chains=32000

total_in_toks=input_chains_per_negative_sampling*(total_chains*avg_token_per_chain + total_chains*avg_subchain_per_chain*avg_tokens_per_subchain)

# %%
max_negatives_per_chain=8
total_out_toks=total_chains*max_negatives_per_chain*avg_token_per_chain + total_chains*avg_subchain_per_chain*max_negatives_per_chain*avg_tokens_per_subchain

# %%
total_cost=total_in_toks/1000000*0.4 + total_out_toks/1000000*1.6

# %%
total_cost
# Out:
# 56.426496

# %%
input_toks=total_chains*avg_token_per_chain +

# %%
28.74 * 1.60
# Out:
# 45.984

# %%
count_df
# Out:
#                                 industry_chain_hierarchy  company_id
# 26643  Non-Profit, Non-Operational & Junk > Non-Profi...        9844
# 26642  Non-Profit, Non-Operational & Junk > Non-Opera...        5492
# 14640  Financial Industry > Financial Institution > A...        5171
# 12920  Enterprise > Service > Outsourcing > Informati...        3950
# 14719  Financial Industry > Financial Institution > B...        2370
# ...                                                  ...         ...
# 2129   Agriculture, Food & Beverage > Food & Beverage...           1
# 2128   Agriculture, Food & Beverage > Food & Beverage...           1
# 13450  Financial Industry > FinTech > Finance & Accou...           1
# 21009  Industrials > Environment > Conservation & Pre...           1
# 12393  Enterprise > Service > Outsourcing > Business ...           1
#
# [32878 rows x 2 columns]
