# %%
endpoint_id=''
import requests

url = "https://api.runpod.ai/v2/bl5llia4wx5b8m/run"
headers = {"Authorization": "Bearer sk-IrR7Bwxtin0haWagUnPrBgq5PurnUz86", "Content-Type": "application/json"}

data = {"input": {
    "messages": [
        {"role": "user", "content": "Write a short poem."}
    ],
    "sampling_params": {"temperature": 0.7, "max_tokens": 100}
}}

response = requests.post(url, headers=headers, json=data)

# %%
response
# Out:
# <Response [401]>
